# %%
# Import necessary libraries
import pandas as pd
# Out:
# C:\Users\Torbjørn\AppData\Local\Temp\ipykernel_10460\225911458.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Construct the relative path to the dataset
dataset_path = '../data/raw/data.csv'

# %%
# Load the dataset from the data/raw directory
dataset = pd.read_csv(dataset_path)

# %%
# Basic Statistics
print(dataset.describe())
# Out:
#            rating        salary  draft_round         age  experience  \
# count  439.000000  4.390000e+02   439.000000  439.000000  439.000000
# mean    76.797267  9.172541e+06     1.086560   26.897494    6.004556
# std      6.251750  1.014423e+07     0.620632    4.139240    3.988566
# min     67.000000  5.000000e+04     0.000000   20.000000    1.000000
# 25%     72.000000  2.028594e+06     1.000000   24.000000    3.000000
# 50%     75.000000  4.764960e+06     1.000000   27.000000    5.000000
# 75%     79.000000  1.267323e+07     1.000000   30.000000    9.000000
# max     97.000000  4.578097e+07     2.000000   40.000000   19.000000
#
#               bmi
# count  439.000000
# mean    24.387965
# std      1.770481
# min     20.321279
# 25%     23.141561
# 50%     24.218011
# 75%     25.492722
# max     32.853790

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=dataset, x='team', y='rating', palette='viridis')
plt.title('Distribution of Ratings Across Teams')
plt.xlabel('Team')
plt.ylabel('Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Torbjørn\AppData\Local\Temp\ipykernel_10460\3490571835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=dataset, x='team', y='rating', palette='viridis')

# %%
import matplotlib.ticker as ticker

average_salary_per_position = dataset.groupby('position')['salary'].mean().reset_index()

plt.figure(figsize=(12, 6))
ax = sns.barplot(data=average_salary_per_position, x='position', y='salary', palette='magma')
plt.title('Average Salary Across Positions')
plt.xlabel('Position')
plt.ylabel('Average Salary')
plt.xticks(rotation=45, ha='right')

# Format y-axis tick labels
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x)))

plt.tight_layout()
plt.show
# Out:
# C:\Users\Torbjørn\AppData\Local\Temp\ipykernel_10460\1164928892.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data=average_salary_per_position, x='position', y='salary', palette='magma')
# <function matplotlib.pyplot.show(close=None, block=None)>
